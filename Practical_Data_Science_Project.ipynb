# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Application_data.csv")
df
# Out:
#        Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0           5008806          M                1             1               0
# 1           5008808          F                0             1               0
# 2           5008809          F                0             1               0
# 3           5008810          F                0             1               0
# 4           5008811          F                0             1               0
# ...             ...              ...        ...           ...             ...
# 25123       5150482          F                1             1               1
# 25124       5150483          F                1             1               1
# 25125       5150484          F                1             1               1
# 25126       5150485          F                1             1               1
# 25127       5150487          M                1             0               0
#
#        Total_Income                                        Income_Type  \
# 0            112500  Working                                       ...
# 1            270000  Commercial associate                          ...
# 2            270000  Commercial associate                          ...
# 3            270000  Commercial associate                          ...
# 4            270000  Commercial associate                          ...
# ...             ...                                                ...
# 25123        157500  Working                                       ...
# 25124        157500  Working                                       ...
# 25125        157500  Working                                       ...
# 25126        157500  Working                                       ...
# 25127        202500  Working                                       ...
#
#                                           Education_Type  \
# 0      Secondary / secondary special                 ...
# 1      Secondary / secondary special                 ...
# 2      Secondary / secondary special                 ...
# 3      Secondary / secondary special                 ...
# 4      Secondary / secondary special                 ...
# ...                                                  ...
# 25123  Secondary / secondary special                 ...
# 25124  Secondary / secondary special                 ...
# 25125  Secondary / secondary special                 ...
# 25126  Secondary / secondary special                 ...
# 25127  Secondary / secondary special                 ...
#
#                                            Family_Status  \
# 0      Married                                       ...
# 1      Single / not married                          ...
# 2      Single / not married                          ...
# 3      Single / not married                          ...
# 4      Single / not married                          ...
# ...                                                  ...
# 25123  Married                                       ...
# 25124  Married                                       ...
# 25125  Married                                       ...
# 25126  Married                                       ...
# 25127  Married                                       ...
#
#                                             Housing_Type  ...  \
# 0      House / apartment                             ...  ...
# 1      House / apartment                             ...  ...
# 2      House / apartment                             ...  ...
# 3      House / apartment                             ...  ...
# 4      House / apartment                             ...  ...
# ...                                                  ...  ...
# 25123  House / apartment                             ...  ...
# 25124  House / apartment                             ...  ...
# 25125  House / apartment                             ...  ...
# 25126  House / apartment                             ...  ...
# 25127  House / apartment                             ...  ...
#
#        Owned_Work_Phone  Owned_Phone  Owned_Email  \
# 0                     0            0            0
# 1                     0            1            1
# 2                     0            1            1
# 3                     0            1            1
# 4                     0            1            1
# ...                 ...          ...          ...
# 25123                 0            0            0
# 25124                 0            0            0
# 25125                 0            0            0
# 25126                 0            0            0
# 25127                 0            0            0
#
#                                                Job_Title Total_Family_Members  \
# 0      Security staff                                ...                    2
# 1      Sales staff                                   ...                    1
# 2      Sales staff                                   ...                    1
# 3      Sales staff                                   ...                    1
# 4      Sales staff                                   ...                    1
# ...                                                  ...                  ...
# 25123  Core staff                                    ...                    3
# 25124  Core staff                                    ...                    3
# 25125  Core staff                                    ...                    3
# 25126  Core staff                                    ...                    3
# 25127  Drivers                                       ...                    2
#
#        Applicant_Age  Years_of_Working  Total_Bad_Debt  Total_Good_Debt  \
# 0                 59                 4               0               30
# 1                 53                 9               0                5
# 2                 53                 9               0                5
# 3                 53                 9               0               27
# 4                 53                 9               0               39
# ...              ...               ...             ...              ...
# 25123             30                 5               0               18
# 25124             30                 5               0               18
# 25125             30                 5               0               13
# 25126             30                 5               0                2
# 25127             54                 6               0               30
#
#        Status
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 25123       1
# 25124       1
# 25125       1
# 25126       1
# 25127       1
#
# [25128 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25128 entries, 0 to 25127
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          25128 non-null  int64
#  1   Applicant_Gender      25128 non-null  object
#  2   Owned_Car             25128 non-null  int64
#  3   Owned_Realty          25128 non-null  int64
#  4   Total_Children        25128 non-null  int64
#  5   Total_Income          25128 non-null  int64
#  6   Income_Type           25128 non-null  object
#  7   Education_Type        25128 non-null  object
#  8   Family_Status         25128 non-null  object
#  9   Housing_Type          25128 non-null  object
#  10  Owned_Mobile_Phone    25128 non-null  int64
#  11  Owned_Work_Phone      25128 non-null  int64
#  12  Owned_Phone           25128 non-null  int64
#  13  Owned_Email           25128 non-null  int64
#  14  Job_Title             25128 non-null  object
#  15  Total_Family_Members  25128 non-null  int64
#  16  Applicant_Age         25128 non-null  int64
#  17  Years_of_Working      25128 non-null  int64
#  18  Total_Bad_Debt        25128 non-null  int64
#  19  Total_Good_Debt       25128 non-null  int64
#  20  Status                25128 non-null  int64
# dtypes: int64(15), object(6)
# memory usage: 4.0+ MB

# %%
df.isnull().sum()
# Out:
# Applicant_ID            0
# Applicant_Gender        0
# Owned_Car               0
# Owned_Realty            0
# Total_Children          0
# Total_Income            0
# Income_Type             0
# Education_Type          0
# Family_Status           0
# Housing_Type            0
# Owned_Mobile_Phone      0
# Owned_Work_Phone        0
# Owned_Phone             0
# Owned_Email             0
# Job_Title               0
# Total_Family_Members    0
# Applicant_Age           0
# Years_of_Working        0
# Total_Bad_Debt          0
# Total_Good_Debt         0
# Status                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Applicant_ID     Owned_Car  Owned_Realty  Total_Children  Total_Income  \
# count  2.512800e+04  25128.000000  25128.000000    25128.000000  2.512800e+04
# mean   5.078835e+06      0.418378      0.654927        0.509472  1.948365e+05
# std    4.194378e+04      0.493303      0.475402        0.762937  1.045211e+05
# min    5.008806e+06      0.000000      0.000000        0.000000  2.700000e+04
# 25%    5.042226e+06      0.000000      0.000000        0.000000  1.350000e+05
# 50%    5.079004e+06      0.000000      1.000000        0.000000  1.800000e+05
# 75%    5.115603e+06      1.000000      1.000000        1.000000  2.250000e+05
# max    5.150487e+06      1.000000      1.000000        5.000000  1.575000e+06
#
#        Owned_Mobile_Phone  Owned_Work_Phone   Owned_Phone   Owned_Email  \
# count             25128.0      25128.000000  25128.000000  25128.000000
# mean                  1.0          0.273758      0.292741      0.100684
# std                   0.0          0.445895      0.455030      0.300916
# min                   1.0          0.000000      0.000000      0.000000
# 25%                   1.0          0.000000      0.000000      0.000000
# 50%                   1.0          0.000000      0.000000      0.000000
# 75%                   1.0          1.000000      1.000000      0.000000
# max                   1.0          1.000000      1.000000      1.000000
#
#        Total_Family_Members  Applicant_Age  Years_of_Working  Total_Bad_Debt  \
# count          25128.000000   25128.000000      25128.000000    25128.000000
# mean               2.291309      40.995503          7.690903        0.333095
# std                0.928871       9.552832          6.415007        1.569448
# min                1.000000      21.000000          1.000000        0.000000
# 25%                2.000000      33.000000          3.000000        0.000000
# 50%                2.000000      40.000000          6.000000        0.000000
# 75%                3.000000      48.000000         10.000000        0.000000
# max                7.000000      68.000000         44.000000       49.000000
#
#        Total_Good_Debt        Status
# count     25128.000000  25128.000000
# mean         21.057545      0.995185
# std          14.735347      0.069227
# min           1.000000      0.000000
# 25%           9.000000      1.000000
# 50%          18.000000      1.000000
# 75%          31.000000      1.000000
# max          61.000000      1.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (25128, 21)

# %%
df.nunique()
# Out:
# Applicant_ID            25128
# Applicant_Gender            2
# Owned_Car                   2
# Owned_Realty                2
# Total_Children              6
# Total_Income              195
# Income_Type                 5
# Education_Type              5
# Family_Status               5
# Housing_Type                6
# Owned_Mobile_Phone          1
# Owned_Work_Phone            2
# Owned_Phone                 2
# Owned_Email                 2
# Job_Title                  18
# Total_Family_Members        7
# Applicant_Age              48
# Years_of_Working           43
# Total_Bad_Debt             33
# Total_Good_Debt            61
# Status                      2
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Initialize a label encoder
label_encoder = LabelEncoder()

# Iterate over each column in the DataFrame
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

# Application_Gender, Income_Type, Education_Type, Family_Status, Housing_Type, Job_Title

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0       5008806                 1          1             1               0
# 1       5008808                 0          0             1               0
# 2       5008809                 0          0             1               0
# 3       5008810                 0          0             1               0
# 4       5008811                 0          0             1               0
#
#    Total_Income  Income_Type  Education_Type  Family_Status  Housing_Type  \
# 0        112500            4               4              1             1
# 1        270000            0               4              3             1
# 2        270000            0               4              3             1
# 3        270000            0               4              3             1
# 4        270000            0               4              3             1
#
#    ...  Owned_Work_Phone  Owned_Phone  Owned_Email  Job_Title  \
# 0  ...                 0            0            0         16
# 1  ...                 0            1            1         14
# 2  ...                 0            1            1         14
# 3  ...                 0            1            1         14
# 4  ...                 0            1            1         14
#
#    Total_Family_Members  Applicant_Age  Years_of_Working  Total_Bad_Debt  \
# 0                     2             59                 4               0
# 1                     1             53                 9               0
# 2                     1             53                 9               0
# 3                     1             53                 9               0
# 4                     1             53                 9               0
#
#    Total_Good_Debt  Status
# 0               30       1
# 1                5       1
# 2                5       1
# 3               27       1
# 4               39       1
#
# [5 rows x 21 columns]

# %%
df.drop(columns=['Applicant_ID'], inplace=True)
df
# Out:
#        Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0                     1          1             1               0
# 1                     0          0             1               0
# 2                     0          0             1               0
# 3                     0          0             1               0
# 4                     0          0             1               0
# ...                 ...        ...           ...             ...
# 25123                 0          1             1               1
# 25124                 0          1             1               1
# 25125                 0          1             1               1
# 25126                 0          1             1               1
# 25127                 1          1             0               0
#
#        Total_Income  Income_Type  Education_Type  Family_Status  Housing_Type  \
# 0            112500            4               4              1             1
# 1            270000            0               4              3             1
# 2            270000            0               4              3             1
# 3            270000            0               4              3             1
# 4            270000            0               4              3             1
# ...             ...          ...             ...            ...           ...
# 25123        157500            4               4              1             1
# 25124        157500            4               4              1             1
# 25125        157500            4               4              1             1
# 25126        157500            4               4              1             1
# 25127        202500            4               4              1             1
#
#        Owned_Mobile_Phone  Owned_Work_Phone  Owned_Phone  Owned_Email  \
# 0                       1                 0            0            0
# 1                       1                 0            1            1
# 2                       1                 0            1            1
# 3                       1                 0            1            1
# 4                       1                 0            1            1
# ...                   ...               ...          ...          ...
# 25123                   1                 0            0            0
# 25124                   1                 0            0            0
# 25125                   1                 0            0            0
# 25126                   1                 0            0            0
# 25127                   1                 0            0            0
#
#        Job_Title  Total_Family_Members  Applicant_Age  Years_of_Working  \
# 0             16                     2             59                 4
# 1             14                     1             53                 9
# 2             14                     1             53                 9
# 3             14                     1             53                 9
# 4             14                     1             53                 9
# ...          ...                   ...            ...               ...
# 25123          3                     3             30                 5
# 25124          3                     3             30                 5
# 25125          3                     3             30                 5
# 25126          3                     3             30                 5
# 25127          4                     2             54                 6
#
#        Total_Bad_Debt  Total_Good_Debt  Status
# 0                   0               30       1
# 1                   0                5       1
# 2                   0                5       1
# 3                   0               27       1
# 4                   0               39       1
# ...               ...              ...     ...
# 25123               0               18       1
# 25124               0               18       1
# 25125               0               13       1
# 25126               0                2       1
# 25127               0               30       1
#
# [25128 rows x 20 columns]

# %% [markdown]
# # EDA

# %%
sns.countplot(x='Status', data=df)
plt.title('Distribution of Status')
plt.show()

# %% [markdown]
# There is a massive imbalance between the target label classes so this imbalance needs to be rectified before modeling.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Education_Type', data=df, order=df['Education_Type'].value_counts().index)
plt.title('Distribution of Education Type')
plt.show()

# 0 - Acadmeic Degree
# 1 - Higher Education
# 2 - Incomplete higher
# 3 - Lower Secondary
# 4 - Secondary / secondary special

# %%
# Distribution of 'NAME_INCOME_TYPE'
plt.figure(figsize=(10, 6))
sns.countplot(y='Income_Type', data=df, order=df['Income_Type'].value_counts().index)
plt.title('Distribution of Income Type')
plt.show()

# 0 - Commercial associate
# 1- Pensioner
# 2 - State Servant
# 3 - Student
# 4 - Working

# %%
plt.figure(figsize=(10, 6))

# Create histograms for 'total_Income' grouped by 'status'
plt.hist([df[df['Status'] == 0]['Total_Income'], df[df['Status'] == 1]['Total_Income']], bins=20, color=['skyblue', 'salmon'], label=['status=0', 'status=1'], alpha=0.7)

plt.title('Histogram of total_Income by Status')
plt.xlabel('total_Income')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3202: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1420: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# # Smote Technique

# %%
pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in /opt/anaconda3/lib/python3.9/site-packages (1.6.2)
# Requirement already satisfied: numpy>=1.18.2 in /opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.23.5)
# Requirement already satisfied: statsmodels>=0.11.1 in /opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (0.13.2)
# Requirement already satisfied: pandas>=1.0.3 in /opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.1.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.3->feature-engine) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.0->feature-engine) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.0->feature-engine) (1.2.0)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11.1->feature-engine) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature-engine) (3.0.9)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import ADASYN
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, DropCorrelatedFeatures
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFromModel, f_classif, RFE, SequentialFeatureSelector
rfe = RFE(estimator = RandomForestClassifier(), n_features_to_select = 10, step=2, verbose = 3)
from sklearn.linear_model import LogisticRegression, Lasso, PassiveAggressiveClassifier, SGDClassifier, RidgeClassifier
from xgboost import XGBClassifier, XGBRFClassifier
xgb = XGBClassifier()
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, PrecisionRecallDisplay, precision_score, accuracy_score, recall_score, f1_score, roc_auc_score, RocCurveDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
smote = ADASYN()

# %%
X = df.drop('Status',axis=1)
y = df['Status']

# %%
smote = ADASYN()
X, y = smote.fit_resample(X, y)

# %%
print("Composition of the target classes:", Counter(y))
# Out:
# Composition of the target classes: Counter({0: 25014, 1: 25007})

# %%
plt.figure(figsize=(8,4))
fig = sns.countplot(y)
plt.title('Distribution of Status')
plt.tight_layout()
plt.show(fig)
plt.close('all')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Train_Test_Split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,shuffle=True,random_state=64)

# %%
pipeline = Pipeline(steps=[
    ('constant',DropConstantFeatures()),
    ('duplicate',DropDuplicateFeatures()),
    ('correlated',DropCorrelatedFeatures())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
X_train.shape, X_test.shape
# Out:
# ((35014, 17), (15007, 17))

# %%
kbest = SelectKBest(k=10,score_func=f_classif)
kbest.fit(X_train,y_train)
# Out:
# SelectKBest()

# %%
selected_features = kbest.get_feature_names_out()
selected_features
# Out:
# array(['Owned_Car', 'Owned_Realty', 'Total_Children', 'Income_Type',
#        'Owned_Work_Phone', 'Owned_Phone', 'Applicant_Age',
#        'Years_of_Working', 'Total_Bad_Debt', 'Total_Good_Debt'],
#       dtype=object)

# %%
perc = SelectPercentile(percentile=40,score_func=f_classif)
perc.fit(X_train,y_train)

selected_features = perc.get_feature_names_out()
selected_features
# Out:
# array(['Owned_Car', 'Owned_Realty', 'Total_Children', 'Owned_Work_Phone',
#        'Owned_Phone', 'Total_Bad_Debt', 'Total_Good_Debt'], dtype=object)

# %%
lasso = SelectFromModel(estimator=Lasso(),max_features=10)
lasso.fit(X_train,y_train)

selected_features = lasso.get_feature_names_out()
selected_features
# Out:
# array(['Total_Bad_Debt', 'Total_Good_Debt'], dtype=object)

# %%
rfe = RFE(estimator=RandomForestClassifier(),n_features_to_select=10,step=2,verbose=3)
rfe.fit(X_train,y_train)
# Out:
# Fitting estimator with 17 features.
# Fitting estimator with 15 features.
# Fitting estimator with 13 features.
# Fitting estimator with 11 features.
# RFE(estimator=RandomForestClassifier(), n_features_to_select=10, step=2,
#     verbose=3)

# %%
selected_features = rfe.get_feature_names_out()
selected_features
# Out:
# array(['Owned_Car', 'Owned_Realty', 'Total_Children', 'Total_Income',
#        'Income_Type', 'Owned_Phone', 'Applicant_Age', 'Years_of_Working',
#        'Total_Bad_Debt', 'Total_Good_Debt'], dtype=object)

# %%
sfs = SequentialFeatureSelector(estimator=RandomForestClassifier(),n_features_to_select=10,direction='forward',cv=4)
sfs.fit(X_train,y_train)

selected_features = sfs.get_feature_names_out()
selected_features
# Out:
# array(['Applicant_Gender', 'Total_Children', 'Total_Income',
#        'Housing_Type', 'Owned_Work_Phone', 'Owned_Phone', 'Owned_Email',
#        'Years_of_Working', 'Total_Bad_Debt', 'Total_Good_Debt'],
#       dtype=object)

# %%
xgb = XGBClassifier()
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
def plot_feature_importances(feat_imp_type):
    feat_imps = xgb.get_booster().get_score(importance_type=feat_imp_type)
    keys = list(feat_imps.keys())
    values = list(feat_imps.values())
    feat_imps_df = pd.DataFrame(data=values, index=keys, columns=["Importance"]).sort_values(by="Importance", ascending=False).reset_index()
    feat_imps_df.rename({'index': 'Feature'},axis=1,inplace=True)
    plt.figure(figsize=(12,8))
    fig = sns.barplot(x='Importance',y='Feature',data=feat_imps_df,orient='horizontal',palette='viridis')
    plt.title(f"{feat_imp_type.title()} Feature Importance")
    plt.show(fig)
    plt.close('all')

# %%
plot_feature_importances('gain')

# %%
plot_feature_importances('weight')

# %%
plot_feature_importances('cover')

# %%
plot_feature_importances('total_cover')

# %%
plot_feature_importances('total_gain')

# %%
final_selected_features = ['Total_Good_Debt','Applicant_Gender','Income_Type','Job_Title','Family_Status','Total_Income','Total_Children','Years_of_Working','Applicant_Age','Total_Bad_Debt']
len(final_selected_features)
# Out:
# 10

# %%
final_X_train = X_train[final_selected_features]
final_X_test = X_test[final_selected_features]

# %%
final_X_train.head()
# Out:
#        Total_Good_Debt  Applicant_Gender  Income_Type  Job_Title  \
# 30377                3                 1            4          8
# 41786                9                 1            4          6
# 32897                6                 1            2          5
# 38271                2                 0            4         14
# 21495               55                 0            4         14
#
#        Family_Status  Total_Income  Total_Children  Years_of_Working  \
# 30377              0         90000               0                 4
# 41786              1        202500               0                 5
# 32897              2        184968               0                 2
# 38271              1        135000               1                 4
# 21495              0        157500               1                11
#
#        Applicant_Age  Total_Bad_Debt
# 30377             33              14
# 41786             40              13
# 32897             37               6
# 38271             41               2
# 21495             32               3

# %%
final_X_test.head()
# Out:
#        Total_Good_Debt  Applicant_Gender  Income_Type  Job_Title  \
# 1228                33                 1            0          4
# 31521                4                 0            0          7
# 44677                3                 0            3          9
# 18065                4                 0            4          2
# 34738                2                 0            3          9
#
#        Family_Status  Total_Income  Total_Children  Years_of_Working  \
# 1228               3        225000               0                 5
# 31521              3        174423               0                 4
# 44677              1        157500               0                12
# 18065              3        207000               0                 7
# 34738              0        294545               0                13
#
#        Applicant_Age  Total_Bad_Debt
# 1228              50               1
# 31521             33              12
# 44677             46               6
# 18065             51               0
# 34738             36               2

# %%
models = []
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
roc_auc_scores = []

# %%
def train_and_evaluate_model(model):
    model.fit(final_X_train,y_train)
    y_pred = model.predict(final_X_test)
    print("Classification Report:")
    print(classification_report(y_test,y_pred))
    print('-'*50)
    ConfusionMatrixDisplay.from_predictions(y_test,y_pred)
    PrecisionRecallDisplay.from_predictions(y_test,y_pred)
    RocCurveDisplay.from_predictions(y_test,y_pred)
    acc = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred,average='macro')
    recall = recall_score(y_test,y_pred,average='macro')
    f1 = f1_score(y_test,y_pred,average='macro')
    roc_auc = roc_auc_score(y_test,y_pred,average='macro')
    accuracy_scores.append(acc)
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    roc_auc_scores.append(roc_auc)
    models.append(model)

# %%
train_and_evaluate_model(LogisticRegression())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7487
#            1       1.00      0.99      1.00      7520
#
#     accuracy                           1.00     15007
#    macro avg       1.00      1.00      1.00     15007
# weighted avg       1.00      1.00      1.00     15007
#
# --------------------------------------------------
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
train_and_evaluate_model(KNeighborsClassifier())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7487
#            1       0.99      0.99      0.99      7520
#
#     accuracy                           0.99     15007
#    macro avg       0.99      0.99      0.99     15007
# weighted avg       0.99      0.99      0.99     15007
#
# --------------------------------------------------

# %%
train_and_evaluate_model(GaussianNB())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90      7487
#            1       0.99      0.78      0.87      7520
#
#     accuracy                           0.89     15007
#    macro avg       0.90      0.89      0.88     15007
# weighted avg       0.90      0.89      0.88     15007
#
# --------------------------------------------------

# %%
train_and_evaluate_model(XGBClassifier())
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7487
#            1       1.00      1.00      1.00      7520
#
#     accuracy                           1.00     15007
#    macro avg       1.00      1.00      1.00     15007
# weighted avg       1.00      1.00      1.00     15007
#
# --------------------------------------------------
